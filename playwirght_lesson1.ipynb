# %% [markdown]
# <a href="https://colab.research.google.com/github/Yun-Syuan/0617_playwright/blob/main/playwirght_lesson1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Hello! Python!")
# Out:
# Hello! Python!

# %%
5
5.5
'5.5'
# Out:
# '5.5'

# %%
print(5 + 5)
print(5 * 5)
print(7 / 3)
print(7 // 3)
# Out:
# 10
# 25
# 2.3333333333333335
# 2
